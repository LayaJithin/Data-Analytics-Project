# %% [markdown]
# ***Title :*** **Data Analysis of "Student Performance Factors" using Python**
#
# **Aim :** To analyze the Student Performance Factors dataset to identify key variables that significantly influence students’ academic score. The goal is to uncover patterns and correlations between demographic, socio-economic, motivational,health and academic factors and to compare the exam score with previous score .

# %% [markdown]
# **Data Loading** :means to import the dataset using pandas ie.,reading data in the csv file using pandas and placing it in the dataframe named "student_data" so that we can analyze,filter and visualize.Dataframe stores our data in tabular form.

# %%
# 1.Data loading from the CSV file.
import pandas as pd
student_data=pd.read_csv("https://github.com/user-attachments/files/22693045/Student.Performance.Factors.csv")
student_data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# **Initial Overview :** It is all about initial observation like number of columns and rows,datatypes,descriptive summary of the dataset(student_data).

# %%
# Prints number of rows and column in the dataset
print("The number of rows and columns in the dataset are :",student_data.shape)
# Out:
# The number of rows and columns in the dataset are : (6607, 20)

# %%
# Prints the first 5 and last 5 rows in the dataset.
print("The First 5 rows of the Student Performance Dataset are: \n",student_data.head(5))
print("\n The Last 5 rows of the Student Performance Dataset are:\n",student_data.tail(5))
# Out:
# The First 5 rows of the Student Performance Dataset are:
#     Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
# ...

# %%
# DataTypes of the Dataset
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
#Descriptive Summary of the Student Performance Dataset
student_data.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %% [markdown]
# **Data Preprocessing :** performing all types cleanup activities like correcting errors,finding the missing values,imputing the null values,removing the duplicate rows so that our data is now ready for exploratory data analysis and visualization.

# %%
# Finding the missing values
missing_values=student_data.isnull().sum()
print("The number of missing values i each column\n",missing_values)
# Out:
# The number of missing values i each column
#  Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
# Imputing the null values with mode value
student_data['Teacher_Quality']=student_data['Teacher_Quality'].fillna(student_data['Teacher_Quality'].mode()[0])
student_data['Parental_Education_Level']=student_data['Parental_Education_Level'].fillna(student_data['Parental_Education_Level'].mode()[0])
student_data['Distance_from_Home']=student_data['Distance_from_Home'].fillna(student_data['Distance_from_Home'].mode()[0])

missing_values=student_data.isnull().sum()
missing_values
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
# Remove the Duplicate rows in the dataset.
student_data=student_data.drop_duplicates()

student_data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# **Exploratory Data Analysis** :It is initial phase of data analysis where the goal is to understand data distribution and relationship,identify the outliers and inconsistencies,summarize key trends and correlation.

# %%
# Exploratory Data Analysis
# Count of each categorical Factors in the Student's Performance

print("Count of Parental Involvement in the Student Perfomance Factor Dataset :\n ",student_data['Parental_Involvement'].value_counts())
print("Count of Gender in the Student Perfomance Factor Dataset : \n ",student_data['Gender'].value_counts())
print("Count of Parental Education Level in the Student Perfomance Factor Dataset : \n",student_data['Parental_Education_Level'].value_counts())
print("Count of Teacher Quality in the Student Perfomance Factor Dataset : \n",student_data['Teacher_Quality'].value_counts())
print("Count of Distance from Home in the Student Perfomance Factor Dataset : \n",student_data['Distance_from_Home'].value_counts())
print("Count of Access to resources in the Student Perfomance Factor Dataset :\n ",student_data['Access_to_Resources'].value_counts())
print("Count of Motivation Level in the Student Perfomance Factor Dataset : \n",student_data['Motivation_Level'].value_counts())
print("Count of Internet Access in the Student Perfomance Factor Dataset : \n",student_data['Internet_Access'].value_counts())
print("Count of Peer influence in the Student Perfomance Factor Dataset : \n",student_data['Peer_Influence'].value_counts())
# Out:
# Count of Parental Involvement in the Student Perfomance Factor Dataset :
#   Parental_Involvement
# Medium    3362
# High      1908
# Low       1337
# Name: count, dtype: int64
# Count of Gender in the Student Perfomance Factor Dataset :
#   Gender
# Male      3814
# Female    2793
# Name: count, dtype: int64
# Count of Parental Education Level in the Student Perfomance Factor Dataset :
#  Parental_Education_Level
# High School     3223
# College         1989
# Postgraduate    1305
# Name: count, dtype: int64
# Count of Teacher Quality in the Student Perfomance Factor Dataset :
#  Teacher_Quality
# Medium    3925
# High      1947
# Low        657
# Name: count, dtype: int64
# Count of Distance from Home in the Student Perfomance Factor Dataset :
#  Distance_from_Home
# Near        3884
# Moderate    1998
# Far          658
# Name: count, dtype: int64
# Count of Access to resources in the Student Perfomance Factor Dataset :
#   Access_to_Resources
# Medium    3319
# High      1975
# ...

# %%
# Unique values in the Parental Education Level,Peer_Influence,School Type
print("Unique values in the Parental Education Level : \n",student_data['Parental_Education_Level'].unique())
print("Unique values in the School Type : \n",student_data['School_Type'].unique())
print("Unique values in the Peer Influence : \n",student_data['Peer_Influence'].unique())
# Out:
# Unique values in the Parental Education Level :
#  ['High School' 'College' 'Postgraduate']
# Unique values in the School Type :
#  ['Public' 'Private']
# Unique values in the Peer Influence :
#  ['Positive' 'Negative' 'Neutral']

# %%
# Filter columns by categorical values
categorical_columns=student_data.select_dtypes(include='object')
categorical_columns
# Out:
#      Parental_Involvement Access_to_Resources Extracurricular_Activities  \
# 0                     Low                High                         No
# 1                     Low              Medium                         No
# 2                  Medium              Medium                        Yes
# 3                     Low              Medium                        Yes
# 4                  Medium              Medium                        Yes
# ...                   ...                 ...                        ...
# 6602                 High              Medium                         No
# 6603                 High              Medium                         No
# 6604               Medium                 Low                        Yes
# 6605                 High                High                        Yes
# 6606               Medium                 Low                        Yes
#
#      Motivation_Level Internet_Access Family_Income Teacher_Quality  \
# ...

# %%
# Filtering column by numerical values
numerical_columns=student_data.select_dtypes(include='number')
numerical_columns
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0                23          84            7               73
# 1                19          64            8               59
# 2                24          98            7               91
# 3                29          89            8               98
# 4                19          92            6               65
# ...             ...         ...          ...              ...
# 6602             25          69            7               76
# 6603             23          76            8               81
# 6604             20          90            6               65
# 6605             10          86            6               91
# 6606             15          67            9               94
#
#       Tutoring_Sessions  Physical_Activity  Exam_Score
# 0                     0                  3          67
# 1                     2                  4          61
# ...

# %%
#Univariate analysis
student_data['Previous_Scores'].hist()# color blue  shows histogram of Previous scores
student_data['Exam_Score'].hist() # color orange shows histogram of Exam scores
student_data['Hours_Studied'].hist()# color green shows histogram of Hours studied
student_data['Sleep_Hours'].hist() # color red shows histogram of Sleep hours
# Out:
# <Axes: >

# %%
student_data['Attendance'].hist() # color blue shows histogram of Attendance
student_data['Tutoring_Sessions'].hist()# color red shows histogram of Tutoring sessions
student_data['Physical_Activity'].hist()# color green shows histogram of Physical activity
# Out:
# <Axes: >

# %%
# Bivariate analysis
student_data.plot.scatter(x='Hours_Studied', y='Previous_Scores')
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Previous_Scores'>

# %%
# Bivariate Analysis
student_data.plot.scatter(x='Hours_Studied', y='Exam_Score')
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Exam_Score'>

# %%
# Correlation Analysis of numerical columns
numerical_columns=student_data.select_dtypes(include='int64')
numerical_columns.corr()
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Hours_Studied           1.000000   -0.009908     0.010977         0.024846
# Attendance             -0.009908    1.000000    -0.015918        -0.020186
# Sleep_Hours             0.010977   -0.015918     1.000000        -0.021750
# Previous_Scores         0.024846   -0.020186    -0.021750         1.000000
# Tutoring_Sessions      -0.014282    0.014324    -0.012216        -0.013122
# Physical_Activity       0.004624   -0.022435    -0.000378        -0.011274
# Exam_Score              0.445455    0.581072    -0.017022         0.175079
#
#                    Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied              -0.014282           0.004624    0.445455
# Attendance                  0.014324          -0.022435    0.581072
# Sleep_Hours                -0.012216          -0.000378   -0.017022
# Previous_Scores            -0.013122          -0.011274    0.175079
# ...

# %%
# Comparison of Exam Score with Previous Score and its status(Derived Column)

student_data['Score_Difference']=student_data['Exam_Score'].sub(student_data['Previous_Scores'])

student_data['Improvement_Status'] = student_data['Score_Difference'].apply(lambda x: 'Improved' if x > 1 else 'Not Improved')
student_data['Improvement_Status']
# Out:
# 0       Not Improved
# 1           Improved
# 2       Not Improved
# 3       Not Improved
# 4           Improved
#             ...
# 6602    Not Improved
# 6603    Not Improved
# 6604        Improved
# 6605    Not Improved
# 6606    Not Improved
# Name: Improvement_Status, Length: 6607, dtype: object

# %%
# Statistical Measures

print("The Mode of the numerical columns: \n",student_data.mode().iloc[0])
# Out:
# The Mode of the columns
#  Hours_Studied                           20
# Attendance                              67
# Parental_Involvement                Medium
# Access_to_Resources                 Medium
# Extracurricular_Activities             Yes
# Sleep_Hours                              7
# Previous_Scores                         66
# Motivation_Level                    Medium
# Internet_Access                        Yes
# Tutoring_Sessions                        1
# Family_Income                          Low
# Teacher_Quality                     Medium
# School_Type                         Public
# Peer_Influence                    Positive
# Physical_Activity                        3
# Learning_Disabilities                   No
# Parental_Education_Level       High School
# Distance_from_Home                    Near
# Gender                                Male
# Exam_Score                              68
# Score_Difference                       -17
# ...

# %%
print("The variance of numerical columns: \n",student_data.var(numeric_only=True))
# Out:
# The variance of numerical columns:
#  Hours_Studied         35.887221
# Attendance           133.344178
# Sleep_Hours            2.155377
# Previous_Scores      207.353789
# Tutoring_Sessions      1.514304
# Physical_Activity      1.063438
# Exam_Score            15.135646
# Score_Difference     202.872971
# dtype: float64

# %%
print("The Standard deviations of the numerical column : \n",student_data.std(numeric_only=True))
# Out:
# The Standard deviations of the numerical column :
#  Hours_Studied         5.990594
# Attendance           11.547475
# Sleep_Hours           1.468120
# Previous_Scores      14.399784
# Tutoring_Sessions     1.230570
# Physical_Activity     1.031231
# Exam_Score            3.890456
# Score_Difference     14.243348
# dtype: float64

# %% [markdown]
# **Visualization**: It converts the data into interpretable grahics like histogram,boxplot,scatterplot,countplot,.. etc using matplotlib and seaborn

# %%
# Visualization
# Visualisation showing the level of parental involvement
import seaborn as sn
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
sn.countplot(x='Parental_Involvement',data=student_data)
plt.xlabel("Parental Involvement")
plt.ylabel("Count")
plt.title("Count of Parental Involvement under each level")
# Out:
# Text(0.5, 1.0, 'Count of Parental Involvement under each level')

# %%
# visualization showing the count of male and female students in the dataset.
plt.figure(figsize=(10,6))
plt.subplot(2,2,2)
sn.countplot(x='Gender',data=student_data)
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Count of Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# Scatter plot showing the Tutoring Session and Physical activity
plt.figure(figsize=(10,6))
sn.scatterplot(x='Physical_Activity',y='Tutoring_Sessions',data=student_data,hue='Gender')
plt.xlabel("Physical Activity")
plt.ylabel("Tutoring Sessions")
plt.title("Time Spent on Tutoring Sessions and Physical Activity by Male and female students")
# Out:
# Text(0.5, 1.0, 'Time Spent on Tutoring Sessions and Physical Activity by Male and female students')

# %%
# barplot showing the Hours studied and Exam Score
plt.figure(figsize=(20,10))
sn.barplot(x='Exam_Score',y='Hours_Studied',data=student_data,hue="Gender")
plt.xlabel("Exam Score")
plt.ylabel("Hours  Studied")
plt.title("Gender wise Hours studied vs Exam Score")
# Out:
# Text(0.5, 1.0, 'Gender wise Hours studied vs Exam Score')

# %%
# barplot showing Parental Involvement vs Exam score
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sn.barplot(x='Parental_Involvement',y='Score_Difference',data=student_data,hue='Gender')
plt.xlabel("Score Difference")
plt.ylabel("Parental Involvement")
plt.title("Gender wise -Parental Involvement Affecting Score ")
# Out:
# Text(0.5, 1.0, 'Gender wise -Parental Involvement Affecting Score ')

# %%
# Piechart showing the Peer influence among students
plt.figure(figsize=(10,6))
plt.pie(student_data['Peer_Influence'].value_counts(),labels=student_data['Peer_Influence'].unique(),autopct='%1.1f%%')
plt.title("Peer Influence")
# Out:
# Text(0.5, 1.0, 'Peer Influence')

# %%
# Pie chart showing Teacher Quality
plt.figure(figsize=(10,6))
plt.pie(student_data['Teacher_Quality'].value_counts(),labels=student_data['Teacher_Quality'].unique(),autopct='%1.1f%%')
plt.title("Teacher Quality")
# Out:
# Text(0.5, 1.0, 'Teacher Quality')

# %%
# Barplot showing the influence of internet access on Score
plt.figure(figsize=(10,6))
sn.barplot(x='Internet_Access',y='Score_Difference',data=student_data)
plt.xlabel("Internet Access")
plt.ylabel("Score Difference")
plt.title("Internet Access Vs Score Difference")
# Out:
# Text(0.5, 1.0, 'Internet Access Vs Score Difference')

# %%
# Barplot showing the average exam score vs Motivation_Level
plt.figure(figsize=(10,6))
order=(student_data.groupby('Motivation_Level')['Exam_Score'].mean().index)
sn.barplot(data=student_data,x='Motivation_Level',y='Exam_Score',order=order)
plt.xlabel("Motivation_Level")
plt.ylabel("Exam Score")
# Out:
# Text(0, 0.5, 'Exam Score')

# %%
# Boxplot showing Family Income vs Exam Score
plt.figure(figsize=(10,6))
sn.boxplot(x='Family_Income',y='Exam_Score',data=student_data)
plt.xlabel("Family Income")
plt.ylabel("Exam Score")
plt.title("Family Income Vs Exam Score")
# Out:
# Text(0.5, 1.0, 'Family Income Vs Exam Score')

# %%
# Correlation between Exam Score,Physical Activity,Attendance,Hours Studied,Tutoring_Sessions,Sleep_Hours
plt.figure(figsize=(10,6))
corr_matrix=student_data[['Exam_Score','Physical_Activity','Attendance','Hours_Studied','Tutoring_Sessions','Sleep_Hours']].corr()

sn.heatmap(corr_matrix,cmap='coolwarm',annot=True)
plt.title("Correlation between Exam Score,Physical Activity,Attendance,Hours Studied,Tutoring_Sessions and Sleep_Hours")
# Out:
# Text(0.5, 1.0, 'Correlation between Exam Score,Physical Activity,Attendance,Hours Studied,Tutoring_Sessions and Sleep_Hours')

# %%
# Barplot showing ExamScore vs Parental Education Level categorized by Family Income
plt.figure(figsize=(10,6))
sn.barplot(data=student_data,x='Parental_Education_Level',y='Exam_Score',hue='Family_Income')
plt.xlabel("Parental_Education_Level")
plt.ylabel("Exam Score")
plt.title("Exam Score vs Parental Education Level categorized by Family Income")
# Out:
# Text(0.5, 1.0, 'Exam Score vs Parental Education Level categorized by Family Income')

# %%
plt.figure(figsize=(10,6))
sn.barplot(data=student_data,x='School_Type',y='Exam_Score',hue='Family_Income')
plt.xlabel("School Type")
plt.ylabel("Exam Score")
plt.title("Exam Score vs School Type categorized by Family Income")
# Out:
# Text(0.5, 1.0, 'Exam Score vs School_Type categorized by Family Income')

# %%
# Score Difference VS Gender categorized by Family Income
plt.figure(figsize=(10,6))
sn.barplot(data=student_data,x='Gender',y='Score_Difference',hue='Family_Income')
plt.xlabel("Gender")
plt.ylabel("Score Difference")
plt.title("Score Difference vs Gender categorized by Family Income")
# Out:
# Text(0.5, 1.0, 'Score Difference vs Gender categorized by Family Income')

# %%
# comparison of family income and school_type
plt.figure(figsize=(10,6))
sn.barplot(data=student_data,x='School_Type',y='Family_Income',hue='Gender')
plt.xlabel("School Type")
plt.ylabel("Family Income")
plt.title("Comparison of family income and school_type")
# Out:
# Text(0.5, 1.0, 'Comparison of family income and school_type')

# %%
# Barplot showing  Parental involvement, family income, and access to resources
plt.figure(figsize=(10,6))
sn.barplot(data=student_data,x='Parental_Involvement',y='Access_to_Resources',hue='Family_Income')
plt.xlabel("Parental Involvement")
plt.ylabel("Access to Resources")
plt.title("Parental involvement, family income, and access to resources ")
# Out:
# Text(0.5, 1.0, 'Parental involvement, family income, and access to resources ')

# %% [markdown]
# **Insight Generation and Report** :
#
# Summary :
#
# The analysis indicates that academic performance is strongly influenced by both academic behavior and socio-economic context.
#
# *   Higher hours studied, attendance, and previous scores show strong
# positive correlation with current performance.
#
# *   Parental involvement, family income, and access to resources contribute meaningfully to consistent improvement.
#
# *   Lifestyle factors such as adequate sleep and regular physical activity support better performance.
# *   Motivation level and peer influence also show moderate influence.
# *   Access to Internet significantly influence student's perfomance.
# *   Share of peer influence and teacher quality under each level is shown.
#
#
#
#
#
#
#
#
#
# .
